# %% [markdown]
# <a href="https://colab.research.google.com/github/nrkfeller/YCBS_notes/blob/master/C7_hyperparameters_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# !wget https://storage.googleapis.com/nicksdemobucket/pima.csv
# Out:
# --2019-06-20 23:34:24--  https://storage.googleapis.com/nicksdemobucket/pima.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.195.128, 2607:f8b0:400e:c09::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.195.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23350 (23K) [application/octet-stream]
# Saving to: ‘pima.csv’
#
# pima.csv            100%[===================>]  22.80K  --.-KB/s    in 0s
#
# 2019-06-20 23:34:29 (96.1 MB/s) - ‘pima.csv’ saved [23350/23350]

# %%
df = pd.read_csv('./pima.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BP  SkinThickness  ...   BMI  DiabetesFunc  Age  Class
# 0            6      148  72             35  ...  33.6         0.627   50      1
# 1            1       85  66             29  ...  26.6         0.351   31      0
# 2            8      183  64              0  ...  23.3         0.672   32      1
# 3            1       89  66             23  ...  28.1         0.167   21      0
# 4            0      137  40             35  ...  43.1         2.288   33      1
#
# [5 rows x 9 columns]

# %%
df['Class'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Class, dtype: int64

# %%
import seaborn as sns

# %%
sns.pairplot(df, hue="Class")
# Out:
# /usr/local/lib/python2.7/dist-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /usr/local/lib/python2.7/dist-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /usr/local/lib/python2.7/dist-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
from sklearn.model_selection import train_test_split, cross_val_score

from sklearn.preprocessing import scale
X = scale(df.drop('Class', axis=1).values)
y = df['Class'].values
X
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505, -0.87137393]])
